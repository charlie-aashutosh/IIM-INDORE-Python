# %% [markdown]
# <a href="https://colab.research.google.com/github/charlie-aashutosh/IIM-INDORE-Python/blob/main/Assignment_IIM_Indore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ![ADABPATBLE.gif](data:image/gif;base64,...)
#   **[YT Channel](https://www.youtube.com/@aashutoshmishra-6-3)**

# %% [markdown]
# Questions

# %% [markdown]
# Q.1. Write a Python program to determine the largest among three numbers entered by the user.

# %% [markdown]
# Q.2. Take an alphabet as input from the user and check if the alphabet is a vowel, consonant or an exception
#
# Vowel - 'a','e','i','o','u'
#
# Exception - 'h', 'y'
#
# Consonant - rest other alphabets

# %% [markdown]
# Q.3. Write a program that appends datatype of elements from a list to a separate list

# %% [markdown]
# Q.4. Write a program to separate even and odd numbers in two distinct lists from a list of numbers of your choice

# %% [markdown]
# Q.5. Write a Python program to check if a given year is a leap year.
#
# Hints :
#
# Check if the year is divisible by 4
#
# Check if the year is divisible by 100, but not divisible by 40
#
# If the year satisfies either of the above conditions, it's a leap year

# %% [markdown]
# Q.6. Write a program to accept the cost price of a bike as input and display the road tax to be paid according to the following crieteria :-
#
# Cost price - 100000 Tax - 15%
#
# Cost price - between 50000 to 100000 Tax - 10%
#
# Cost price - less than 50000 Tax - 5%

# %% [markdown]
# Q.7. Write a program to calculate the electricity bill by accepting the number of units consumed by the user as input. Use the following price chart for reference :-
#
# Price of first 100 units - no charge
#
# Price of next 100 units - Rs 5/- per unit
#
# After 200 units - Rs 10/- per unit
